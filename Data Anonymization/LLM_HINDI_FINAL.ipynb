# %%
# transformers: Provides tools for NLP, pandas: Handles data analysis and manipulation
# !pip install transformers pandas
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.47.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2024.12.14)

# %%
# Import necessary libraries
#import pandas as pd  # Used for data manipulation and analysis
#from transformers import pipeline  # Provides access to Hugging Face transformers for NLP tasks
#from sklearn.feature_extraction.text import CountVectorizer  # Used for calculating the uniqueness score of text

# Load a Hugging Face pipeline for Named Entity Recognition (NER) specific to Hindi text
# The model "ai4bharat/indic-bert" is pre-trained for handling Indic languages
# ner_pipeline = pipeline("ner", grouped_entities=True, model="ai4bharat/indic-bert")

# Load the dataset containing Hindi text
# Ensure the dataset is properly formatted and contains Hindi language content
# data = pd.read_csv('/content/hindi_dataset_12_01_2024_cleaned.csv')

# Get the list of all column names in the dataset
# These columns will be targeted for pseudonymization
# target_columns = data.columns.tolist()

# Function to calculate a uniqueness score for a given text
# def calculate_score(text):
   # vectorizer = CountVectorizer()  # Initialize a CountVectorizer to tokenize and count unique words
   # matrix = vectorizer.fit_transform([text])  # Fit the text to the vectorizer and create a word frequency matrix
   # return len(vectorizer.get_feature_names_out())  # Return the count of unique words in the text

# Calculate pre-pseudonymization uniqueness scores for each row in the dataset
# Combines all text from the target columns in a row, computes a uniqueness score, and stores it in a new column
# data['Original_Score'] = data[target_columns].apply(
    # lambda row: calculate_score(' '.join(row.dropna().astype(str))), axis=1
# )

# Function to pseudonymize Hindi text using the Hugging Face NER pipeline
# def pseudonymize_with_transformers(text):
  #  """
    # Uses a Hugging Face NER pipeline to identify and replace sensitive entities in Hindi text with placeholders.
   # """
   # try:
       # entities = ner_pipeline(text)  # Perform NER on the text to identify entities
        # pseudonymized_text = text  # Start with the original text
        # for entity in entities:
            # Check if the entity type is one of the targeted types (PER, ORG, LOC)
            # if entity["entity_group"] in ["PER", "ORG", "LOC"]:
                # Replace the identified entity in the text with a placeholder
               # pseudonymized_text = pseudonymized_text.replace(entity["word"], f"{entity['entity_group']}_REPLACEMENT")
        # return pseudonymized_text  # Return the pseudonymized text
    # except Exception as e:
        # Handle exceptions during the pseudonymization process
        # print(f"Error during pseudonymization: {e}")
        # return text  # Return the original text if an error occurs

# Apply the pseudonymization process to all target columns in the dataset
# Create new columns prefixed with 'Pseudonymized_' to store the pseudonymized text
# for column in target_columns:
    # data[f'Pseudonymized_{column}'] = data[column].apply(
        # lambda x: pseudonymize_with_transformers(str(x)) if pd.notnull(x) else x
    # )

# Calculate post-pseudonymization uniqueness scores for each row in the dataset
# Combines all pseudonymized text from the target columns in a row and computes a uniqueness score
# data['Pseudonymized_Score'] = data[[f'Pseudonymized_{col}' for col in target_columns]].apply(
    # lambda row: calculate_score(' '.join(row.dropna().astype(str))), axis=1
# )

# Calculate the difference in uniqueness scores before and after pseudonymization
# The difference indicates the impact of pseudonymization on the uniqueness of the text
# data['Score_Difference'] = data['Original_Score'] - data['Pseudonymized_Score']

# Save the pseudonymized dataset, including the new scores, to a new CSV file
# output_file = '/content/updated_result_with_hindi_transformers.csv'  # Specify the output file path
# data.to_csv(output_file, index=False)  # Write the DataFrame to a CSV file without including the index

# Display a sample of the data for verification
# Include columns for original and pseudonymized scores, score differences, and the pseudonymized text
# comparison_columns = ['Original_Score', 'Pseudonymized_Score', 'Score_Difference'] + [
    # col for col in data.columns if 'Pseudonymized' in col or col in target_columns
# ]
# sample_data = data[comparison_columns].head(10)  # Select the first 10 rows for display
# print("Sample Data with Original and Pseudonymized Columns:")  # Print a header for clarity
# print(sample_data)  # Print the sample data for comparison
# print(f"\nPseudonymized data saved to '{output_file}'")  # Confirm the output file path to the user

# %%
# # Importing required libraries
# import pandas as pd
# from transformers import pipeline
# import matplotlib.pyplot as plt
# import numpy as np

# # Load dataset and initialize NER pipeline
# data = pd.read_csv('/content/hindi_dataset_12_01_2024_cleaned.csv')

# # Change model to Hindi-specific one
# ner_pipeline = pipeline("ner", model="xlm-roberta-base", grouped_entities=True)

# # Initialize counters for visualization
# entity_counts = {
#     'before': {'PER': 0, 'ORG': 0, 'LOC': 0},
#     'after': {'PER': 0, 'ORG': 0, 'LOC': 0}
# }

# # Pseudonymization function
# def pseudonymize_with_transformers(text):
#     """
#     Returns pseudonymized text and list of replaced entities
#     """
#     try:
#         # Run NER on the text
#         entities = ner_pipeline(text)
#         original_text = text
#         pseudonymized_text = text
#         replaced_entities = []

#         # Process entities in reverse order
#         for entity in reversed(sorted(entities, key=lambda x: x['start'])):
#             if entity["entity_group"] in ["PER", "ORG", "LOC"]:
#                 start = entity["start"]
#                 end = entity["end"]
#                 original_entity = original_text[start:end]
#                 replacement = f"{entity['entity_group']}_REPLACEMENT"

#                 # Update text and counters
#                 pseudonymized_text = pseudonymized_text[:start] + replacement + pseudonymized_text[end:]
#                 replaced_entities.append({
#                     'entity_type': entity['entity_group'],
#                     'original_value': original_entity,
#                     'replacement_value': replacement
#                 })

#                 # Update visualization counters
#                 entity_counts['before'][entity['entity_group']] += 1
#                 entity_counts['after'][entity['entity_group']] += 1

#         return pseudonymized_text, replaced_entities

#     except Exception as e:
#         print(f"Error during pseudonymization: {e}")
#         return text, []

# %%
# Importing required libraries
#import pandas as pd
#from transformers import pipeline
#import matplotlib.pyplot as plt
#import numpy as np

# Load dataset and initialize NER pipeline
#data = pd.read_csv('/content/hindi_dataset_12_01_2024_cleaned.csv')

# Change model to Hindi-specific one
# ner_pipeline = pipeline("ner", model="ai4bharat/IndicNER", grouped_entities=True)
# ner_pipeline = pipeline("ner", model="cfilt/HiNER-original-xlm-roberta-large", aggregation_strategy="simple")
#ner_pipeline = pipeline("ner", model="cfilt/HiNER-original-xlm-roberta-large", aggregation_strategy="simple", grouped_entities=True)
# ner_pipeline = pipeline("ner", model="Davlan/bert-base-multilingual-cased-ner-hrl", aggregation_strategy="simple")

# Use a pipeline as a high-level helper
#target_columns = data.columns.tolist()


# Initialize counters for visualization
#entity_counts = {
    #'before': {'PERSON': 0, 'ORGANIZATION': 0, 'LOCATION': 0},
    #'after': {'PERSON': 0, 'ORGANIZATION': 0, 'LOCATION': 0}
#}

# Pseudonymization function
#def pseudonymize_with_transformers(text):
    #"""
    #Returns pseudonymized text and list of replaced entities
   # """
    #try:
        # Run NER on the text
       # entities = ner_pipeline(text)
        #original_text = text
        #pseudonymized_text = text
       # replaced_entities = []

        # Process entities in reverse order
       # if len(entities) > 0:
         # reversed(sorted(entities, key=lambda x: x['start']))

       # for entity in reversed(sorted(entities, key=lambda x: x['start'])):
          #  if entity["entity_group"] in ["PERSON", "ORGANIZATION", "LOCATION"] and (entity["end"] - entity["start"] > 2):
               # start = entity["start"]
               # end = entity["end"]
               # original_entity = original_text[start:end]
               # replacement = f"{entity['entity_group']}_REPLACEMENT"

                # Update text and counters
               # pseudonymized_text = pseudonymized_text[:start] + replacement + pseudonymized_text[end:]
               # replaced_entities.append({
                   # 'entity_type': entity['entity_group'],
                   # 'original_value': original_entity,
                   # 'replacement_value': replacement
               # })

                # Update visualization counters
               # entity_counts['before'][entity['entity_group']] += 1
               # entity_counts['after'][entity['entity_group']] += 1

        #return pseudonymized_text, replaced_entities

    #except Exception as e:
       # print(f"Error during pseudonymization: {e}")
       # return text, []

# Process data and build outputs
#comparison_records = []

# Iterate over each row in the dataset
#for row_idx, row in data.iterrows():
    #row_changes = []
    # Use all columns from the dataset
   # for col_name in target_columns:
        #original_value = str(row[col_name]) if pd.notnull(row[col_name]) else ""
        #pseudonymized_value, entities = pseudonymize_with_transformers(original_value)

        # Update DataFrame with pseudonymized values
        #pseudonymized_column_name = f'Pseudonymized_{col_name}'
       # data.at[row_idx, pseudonymized_column_name] = pseudonymized_value

        # Record changes
        #if entities:
          # for entity in entities:
               # row_changes.append({
                   # 'Row': row_idx + 1,
                    #'Column': col_name,
                    #'Entity Type': entity['entity_type'],
                   #'Original': entity['original_value'],
                    #'Replacement': entity['replacement_value'],
                  #  'Full Pseudonymized': pseudonymized_value
               # })

    #if row_changes:
#        comparison_records.extend(row_changes)

# ======================
# 1. Display Table
# ======================
#if comparison_records:
   # comparison_df = pd.DataFrame(comparison_records)[[
        #'Row', 'Column', 'Entity Type', 'Original', 'Replacement',
        #'Full Original', 'Full Pseudonymized'
   # ]]

   # print("\n=== Detailed Changes Table ===")
   # print(comparison_df.to_string(index=False, max_colwidth=30))
#else:
   # print("No entities replaced.")

# %%
# # ======================
# # 2. Generate Plot
# # ======================

# labels = ['Person', 'Organization', 'Location']
# before = [entity_counts['before'][k] for k in ['PERSON', 'ORGANIZATION', 'LOCATION']]
# after = [entity_counts['after'][k] for k in ['PERSON', 'ORGANIZATION', 'LOCATION']]

# x = np.arange(len(labels))
# width = 0.35

# plt.figure(figsize=(12, 6))
# plt.bar(x - width/2, before, width, label='Original', color='#4CAF50')
# plt.bar(x + width/2, after, width, label='Pseudonymized', color='#FF5722')

# plt.xticks(x, labels)
# plt.ylabel('Entity Count')
# plt.title('Entity Replacement Effectiveness')
# plt.legend()
# plt.grid(axis='y', alpha=0.3)

# # Add annotations
# for i, (b, a) in enumerate(zip(before, after)):
#     plt.text(i - width/2, b + 0.5, f'{b}', ha='center', va='bottom')
#     plt.text(i + width/2, a + 0.5, f'{a}', ha='center', va='bottom')
#     percentage = (a/b)*100 if b > 0 else 0
#     plt.text(i, max(b,a) + 5, f'{percentage:.1f}%', ha='center', fontweight='bold')

# plt.tight_layout()
# print("\n=== Visualization ===")
# plt.show()

# %%
# Importing required libraries
import pandas as pd
from transformers import pipeline
import matplotlib.pyplot as plt
import numpy as np

# Load dataset and initialize NER pipeline
data = pd.read_csv('/content/hindi_dataset_12_01_2024_cleaned.csv')

# Change model to Hindi-specific one
ner_pipeline = pipeline("ner", model="ai4bharat/IndicNER", grouped_entities=True, aggregation_strategy="simple")
# ner_pipeline = pipeline("ner", model="cfilt/HiNER-original-xlm-roberta-large", aggregation_strategy="simple")
# ner_pipeline = pipeline("ner", model="cfilt/HiNER-original-xlm-roberta-large", aggregation_strategy="simple", grouped_entities=True)
# ner_pipeline = pipeline("ner", model="Davlan/bert-base-multilingual-cased-ner-hrl", aggregation_strategy="simple")

# Use a pipeline as a high-level helper
target_columns = data.columns.tolist()


# Initialize counters for visualization
entity_counts = {
    'before': {'PER': 0, 'ORG': 0, 'LOC': 0},
    'after': {'PER': 0, 'ORG': 0, 'LOC': 0}
}

# Pseudonymization function
def pseudonymize_with_transformers(text):
    """
    Returns pseudonymized text and list of replaced entities
    """
    try:
        # Run NER on the text
        entities = ner_pipeline(text)
        original_text = text
        pseudonymized_text = text
        replaced_entities = []

        # Process entities in reverse order
        if len(entities) > 0:
          reversed(sorted(entities, key=lambda x: x['start']))

        for entity in reversed(sorted(entities, key=lambda x: x['start'])):
            if entity["entity_group"] in ["PER", "ORG", "LOC"] and (entity["end"] - entity["start"] > 2):
                start = entity["start"]
                end = entity["end"]
                original_entity = original_text[start:end]
                replacement = f"{entity['entity_group']}_REPLACEMENT"

                # Update text and counters
                pseudonymized_text = pseudonymized_text[:start] + replacement + pseudonymized_text[end:]
                replaced_entities.append({
                    'entity_type': entity['entity_group'],
                    'original_value': original_entity,
                    'replacement_value': replacement
                })

                # Update visualization counters
                entity_counts['before'][entity['entity_group']] += 1
                entity_counts['after'][entity['entity_group']] += 1

        return pseudonymized_text, replaced_entities

    except Exception as e:
        print(f"Error during pseudonymization: {e}")
        return text, []

# Process data and build outputs
comparison_records = []

# Iterate over each row in the dataset
for row_idx, row in data.iterrows():
    row_changes = []
    # Use all columns from the dataset
    for col_name in target_columns:
        original_value = str(row[col_name]) if pd.notnull(row[col_name]) else ""
        pseudonymized_value, entities = pseudonymize_with_transformers(original_value)

        # Update DataFrame with pseudonymized values
        pseudonymized_column_name = f'Pseudonymized_{col_name}'
        data.at[row_idx, pseudonymized_column_name] = pseudonymized_value

        # Record changes
        if entities:
            for entity in entities:
                row_changes.append({
                    'Row': row_idx + 1,
                    'Column': col_name,
                    'Entity Type': entity['entity_type'],
                    'Original': entity['original_value'],
                    'Replacement': entity['replacement_value'],
                    'Full Original': original_value,
                    'Full Pseudonymized': pseudonymized_value
                })

    if row_changes:
        comparison_records.extend(row_changes)

# ======================
# 1. Display Table
# ======================
if comparison_records:
    comparison_df = pd.DataFrame(comparison_records)[[
        'Row', 'Column', 'Entity Type', 'Original', 'Replacement',
        'Full Original', 'Full Pseudonymized'
    ]]

    print("\n=== Detailed Changes Table ===")
    print(comparison_df.to_string(index=False, max_colwidth=30))
else:
    print("No entities replaced.")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/667M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/346 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/872k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.72M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cuda:0
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/token_classification.py:170: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="AggregationStrategy.SIMPLE"` instead.
#   warnings.warn(
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# === Detailed Changes Table ===
#  Row    Column Entity Type              Original     Replacement                  Full Original             Full Pseudonymized
#   33  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#   44  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#   47  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#   52   Remarks         ORG                   संर ORG_REPLACEMENT                    संरक्षक2012        ORG_REPLACEMENTक्षक2012
#   56  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#   62  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#   75  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  104  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  106  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
#  137  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
#  144  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  149  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  182  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  219  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  223  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  239  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
#  280  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
#  281  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  294  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  320  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  321  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  405  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
#  415  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  443  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  450  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  451  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
#  481  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
#  508  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  524  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
#  539  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  561  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  586  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
#  605  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  620  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  676  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
#  695  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
#  705  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  785  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  786  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
#  787  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  804  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
#  808  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  860  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  876  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  896  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  914  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
#  948  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  949  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
#  960  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
#  989  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
# 1003  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
# 1015  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
# 1045  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
# 1049  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
# 1056  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
# 1087   Remarks         ORG               all com ORG_REPLACEMENT मरीज खुश हैं,कोई दर्द नहीं,... मरीज खुश हैं,कोई दर्द नहीं,...
# 1103  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
# 1175  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
# 1202  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
# 1262  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
# 1319  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
# 1420   Remarks         ORG                   com ORG_REPLACEMENT मरीज खुश हैं,कोई दर्द नहीं,... मरीज खुश हैं,कोई दर्द नहीं,...
# 1465   Remarks         PER                walker PER_REPLACEMENT कोई दर्द नहीं,walking with ... कोई दर्द नहीं,walking with ...
# 1473   Remarks         PER                   लंग PER_REPLACEMENT लंगड़ा, कोई दर्द नहीं, सब ठ... PER_REPLACEMENTड़ा, कोई दर्...
# 1481   Remarks         ORG                   IMS ORG_REPLACEMENT चलने में कठिनाई,कोई दर्द नह... चलने में कठिनाई,कोई दर्द नह...
# 1537   Remarks         PER                walker PER_REPLACEMENT cup loosening, walking with... cup loosening, walking with...
# 1549   Remarks         PER                   bed PER_REPLACEMENT    bedridden, not मरीज खुश हैं PER_REPLACEMENTridden, not ...
# 1576   Remarks         ORG                   com ORG_REPLACEMENT मरीज खुश हैं,कोई दर्द नहीं,... मरीज खुश हैं,कोई दर्द नहीं,...
# 1681   Remarks         ORG                   ace ORG_REPLACEMENT acet 2015, thr2016.[cup los... ORG_REPLACEMENTt 2015, thr2...
# 1682   Remarks         ORG                   all ORG_REPLACEMENT Talk to  daughter, back pai... Talk to  daughter, back pai...
# 1684   Remarks         PER                   Sen PER_REPLACEMENT Talk to son ,1st Sx by Dr S... Talk to son ,1st Sx by Dr P...
# 1693   Remarks         ORG               all com ORG_REPLACEMENT          all comf , no problem  ORG_REPLACEMENTf , no problem
# 1708   Remarks         ORG                   com ORG_REPLACEMENT             comf,कोई दर्द नहीं ORG_REPLACEMENTf,कोई दर्द नहीं
# 1711   Remarks         ORG                   com ORG_REPLACEMENT       Talk to son , fine, comf Talk to son , fine, ORG_REP...
# 1727   Remarks         PER                  will PER_REPLACEMENT burning sensation foot, wil... burning sensation PER_REPLA...
# 1727   Remarks         PER                  foot PER_REPLACEMENT burning sensation foot, wil... burning sensation PER_REPLA...
# 1736   Remarks         ORG                ESPIRE ORG_REPLACEMENT                        ESPIRED               ORG_REPLACEMENTD
# 1747   Remarks         ORG                   Com ORG_REPLACEMENT Comf,सभी ठीक है, मरीज खुश ह... ORG_REPLACEMENTf,सभी ठीक है...
# 1748   Remarks         LOC                  fine LOC_REPLACEMENT slight pain, Else finewill ... slight pain, Else LOC_REPLA...
# 1771   Remarks         LOC                कप रिव LOC_REPLACEMENT    डिसलोकेशन के कारण कप रिवीजन डिसलोकेशन के कारण LOC_REPLA...
# 1777   Remarks         ORG             एसीट टांड ORG_REPLACEMENT एसीट टांडा 2017, लंगड़ाना+,... ORG_REPLACEMENTा 2017, लंगड...
# 1780   Remarks         ORG                कप रिव ORG_REPLACEMENT 2 वर्षों में कप रिवीजन के स... 2 वर्षों में ORG_REPLACEMEN...
# 1789   Remarks         PER                   सेन PER_REPLACEMENT आराम से, कोई दर्द नहीं, एसी... आराम से, कोई दर्द नहीं, ORG...
# 1789   Remarks         ORG         एसीटी लुधियान ORG_REPLACEMENT आराम से, कोई दर्द नहीं, एसी... आराम से, कोई दर्द नहीं, ORG...
# 1798   Remarks         PER                   Sen PER_REPLACEMENT Talk to son , loosing impla... Talk to son , loosing impla...
# 1800   Remarks         LOC                   thi LOC_REPLACEMENT Pain in thigh , walking 1 k... Pain in LOC_REPLACEMENTgh ,...
# 1806   Remarks         ORG                   com ORG_REPLACEMENT comf,कोई दर्द नहीं , no com... ORG_REPLACEMENTf,कोई दर्द न...
# 1807   Remarks         ORG                   all ORG_REPLACEMENT          all , कोई शिकायत नहीं ORG_REPLACEMENT , कोई शिकाय...
# 1808  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
# 1812  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, कूल्हे क... LOC_REPLACEMENTोइन में असहज...
# 1860   Remarks         ORG                   ori ORG_REPLACEMENT आर्थ्राइटिक कूल्हे oct 2013... आर्थ्राइटिक कूल्हे oct 2013...
# 1872   Remarks         ORG                   Com ORG_REPLACEMENT         Comf , कोई शिकायत नहीं ORG_REPLACEMENTf , कोई शिका...
# 1873  symptoms         LOC                   ग्र LOC_REPLACEMENT ग्रोइन में असहजता, सीमित गत... LOC_REPLACEMENTोइन में असहज...
# 1877   Remarks         ORG                   ace ORG_REPLACEMENT acet in अप्रैल 18. thr in j... ORG_REPLACEMENTt in अप्रैल ...
# 1878  symptoms         LOC                   पैर LOC_REPLACEMENT पैरों में ग्रीव क्षेत्र में... LOC_REPLACEMENTों में ग्रीव...
# 1879   Remarks         ORG                   com ORG_REPLACEMENT comf,कोई दर्द नहीं , सभी ठी... ORG_REPLACEMENTf,कोई दर्द न...
# 1884   Remarks         LOC                दिल्ली LOC_REPLACEMENT पत्नी से बात की, नस से संबं... पत्नी से बात की, नस से संबं...
# 1886   Remarks         PER           er Aggarwal PER_REPLACEMENT Rev dr sameer Aggarwal , pa... Rev dr PER_REPLACEMENTPER_R...
# 1886   Remarks         PER                  same PER_REPLACEMENT Rev dr sameer Aggarwal , pa... Rev dr PER_REPLACEMENTPER_R...
# 1889 Diagnosis         PER                  ॉब ए PER_REPLACEMENT             कॉब एंगल का अनुमान  कPER_REPLACEMENTंगल का अनुमान
# 1891 Diagnosis         PER                  ॉब ए PER_REPLACEMENT             कॉब एंगल का अनुमान  कPER_REPLACEMENTंगल का अनुमान
# 1892 Diagnosis         PER                  ॉब ए PER_REPLACEMENT 3D स्कैन से कॉब एंगल का अनुमान 3D स्कैन से कPER_REPLACEMEN...
# 1904 Diagnosis         ORG                   ट्र ORG_REPLACEMENT स्ट्रॉमा पैरामीटर से सर्वाइ... स्ORG_REPLACEMENTॉमा पैरामी...
# 1906 Diagnosis         ORG                   स्क ORG_REPLACEMENT    स्कोलियोसिस सर्जरी की योजना ORG_REPLACEMENTोलियोसिस सर्...
# 1918 Diagnosis         ORG                 फ्रैक ORG_REPLACEMENT      ऑस्टियोपोरोसिस फ्रैक्चर्स ऑORG_REPLACEMENTियोपोरोसिस ...
# 1918 Diagnosis         ORG                   स्ट ORG_REPLACEMENT      ऑस्टियोपोरोसिस फ्रैक्चर्स ऑORG_REPLACEMENTियोपोरोसिस ...
# 1927 Diagnosis         PER                  ॉब ए PER_REPLACEMENT             कॉब एंगल का अनुमान  कPER_REPLACEMENTंगल का अनुमान
# 1929 Diagnosis         PER                  ॉब ए PER_REPLACEMENT             कॉब एंगल का अनुमान  कPER_REPLACEMENTंगल का अनुमान
# 1930 Diagnosis         PER                  ॉब ए PER_REPLACEMENT 3D स्कैन से कॉब एंगल का अनुमान 3D स्कैन से कPER_REPLACEMEN...
# 1942 Diagnosis         ORG                   ट्र ORG_REPLACEMENT स्ट्रॉमा पैरामीटर से सर्वाइ... स्ORG_REPLACEMENTॉमा पैरामी...
# 1944 Diagnosis         ORG                   स्क ORG_REPLACEMENT    स्कोलियोसिस सर्जरी की योजना ORG_REPLACEMENTोलियोसिस सर्...
# 1956 Diagnosis         ORG                 फ्रैक ORG_REPLACEMENT      ऑस्टियोपोरोसिस फ्रैक्चर्स ऑORG_REPLACEMENTियोपोरोसिस ...
# 1956 Diagnosis         ORG                   स्ट ORG_REPLACEMENT      ऑस्टियोपोरोसिस फ्रैक्चर्स ऑORG_REPLACEMENTियोपोरोसिस ...
# 1968 Diagnosis         ORG                 फ्रैक ORG_REPLACEMENT      ऑस्टियोपोरोसिस फ्रैक्चर्स ऑORG_REPLACEMENTियोपोरोसिस ...
# 1968 Diagnosis         ORG                   स्ट ORG_REPLACEMENT      ऑस्टियोपोरोसिस फ्रैक्चर्स ऑORG_REPLACEMENTियोपोरोसिस ...
# 1989 Diagnosis         ORG           िम्ब सर्वाइ ORG_REPLACEMENT                 लिम्ब सर्वाइवल             लORG_REPLACEMENTवल
# 2017 Diagnosis         ORG                   स्ट ORG_REPLACEMENT ऑस्टियोगठिया जोखिम पूर्वानुमान ऑORG_REPLACEMENTियोगठिया जो...
# 2035 Diagnosis         ORG                   USS ORG_REPLACEMENT USS का उपयोग करके रीढ़ के स... ORG_REPLACEMENT का उपयोग कर...
# 2042 Diagnosis         ORG                   USS ORG_REPLACEMENT USS का उपयोग करके रीढ़ के स... ORG_REPLACEMENT का उपयोग कर...
# 2058 Diagnosis         ORG    ियोगठिया गेट विश्ल ORG_REPLACEMENT      ऑस्टियोगठिया गेट विश्लेषण ऑORG_REPLACEMENTORG_REPLACE...
# 2058 Diagnosis         ORG                   स्ट ORG_REPLACEMENT      ऑस्टियोगठिया गेट विश्लेषण ऑORG_REPLACEMENTORG_REPLACE...
# 2064 Diagnosis         ORG रोक्लिया डिस्प्लेसिया ORG_REPLACEMENT ट्रोक्लिया डिस्प्लेसिया स्ट...     ट्ORG_REPLACEMENT स्टेजिंग
# 2070 Diagnosis         ORG          लंबर स्टेनोस ORG_REPLACEMENT                 लंबर स्टेनोसिस              ORG_REPLACEMENTिस
# 2071 Diagnosis         ORG                   ग्र ORG_REPLACEMENT  रेडियोग्राफ से फ्रैक्चर पहचान रेडियोORG_REPLACEMENTाफ से ...
# 2103 Diagnosis         ORG                   ORI ORG_REPLACEMENT मृत्यु दर और ORIF के बाद पर... मृत्यु दर और ORG_REPLACEMEN...
# 2121 Diagnosis         ORG                   यूस ORG_REPLACEMENT क्यूसीटी से ऑस्टियोपोरोसिस ... क्ORG_REPLACEMENTीटी से ऑस्...
# 2122 Diagnosis         ORG                   यूस ORG_REPLACEMENT क्यूसीटी से कशेरुका की ताकत... क्ORG_REPLACEMENTीटी से कशे...
# 2129 Diagnosis         ORG                   ग्र ORG_REPLACEMENT रेडियोग्राफ से फ्रैक्चर की ... रेडियोORG_REPLACEMENTाफ से ...

# %%
# ======================
# 2. Generate Plot
# ======================

labels = ['Person', 'Organization', 'Location']
before = [entity_counts['before'][k] for k in ['PER', 'ORG', 'LOC']]
after = [entity_counts['after'][k] for k in ['PER', 'ORG', 'LOC']]

x = np.arange(len(labels))
width = 0.35

plt.figure(figsize=(12, 6))
plt.bar(x - width/2, before, width, label='Original', color='#4CAF50')
plt.bar(x + width/2, after, width, label='Pseudonymized', color='#FF5722')

plt.xticks(x, labels)
plt.ylabel('Entity Count')
plt.title('Entity Replacement Effectiveness')
plt.legend()
plt.grid(axis='y', alpha=0.3)

# Add annotations
for i, (b, a) in enumerate(zip(before, after)):
    plt.text(i - width/2, b + 0.5, f'{b}', ha='center', va='bottom')
    plt.text(i + width/2, a + 0.5, f'{a}', ha='center', va='bottom')
    percentage = (a/b)*100 if b > 0 else 0
    plt.text(i, max(b,a) + 5, f'{percentage:.1f}%', ha='center', fontweight='bold')

plt.tight_layout()
print("\n=== Visualization ===")
plt.show()
# Out:
# === Visualization ===

# %%
output_path = '/content/updated_result_with_AI_HINDI.csv'
data.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"\nSaved pseudonymized data to: {output_path}")
# Out:
# Saved pseudonymized data to: /content/updated_result_with_AI_HINDI.csv

# %%
# ======================
# Calculate Percentages
# ======================

def calculate_percentages(before, after):
    percentages = {}
    for ent_type in ['PER', 'ORG', 'LOC']:
        try:
            percentages[ent_type] = (after[ent_type] / before[ent_type]) * 100
        except ZeroDivisionError:
            percentages[ent_type] = 0.0
    return percentages

# Get percentages
replacement_percentages = calculate_percentages(
    entity_counts['before'],
    entity_counts['after']
)

# Create and display percentage table
percentage_df = pd.DataFrame({
    'Entity Type': ['Person (PER)', 'Organization (ORG)', 'Location (LOC)'],
    'Total Entities': [entity_counts['before']['PER'],
                      entity_counts['before']['ORG'],
                      entity_counts['before']['LOC']],
    'Replaced Entities': [entity_counts['after']['PER'],
                         entity_counts['after']['ORG'],
                         entity_counts['after']['LOC']],
    'Replacement Rate (%)': [replacement_percentages['PER'],
                            replacement_percentages['ORG'],
                            replacement_percentages['LOC']]
})

print("\n=== Replacement Effectiveness Summary ===")
print(percentage_df.to_string(index=False, float_format="%.1f"))
# Out:
# === Replacement Effectiveness Summary ===
#        Entity Type  Total Entities  Replaced Entities  Replacement Rate (%)
#       Person (PER)              17                 17                 100.0
# Organization (ORG)              44                 44                 100.0
#     Location (LOC)              67                 67                 100.0
